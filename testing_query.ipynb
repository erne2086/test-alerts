# %% [markdown]
# # This notebook is to help us test the queries and define the ones to track the alerts

# %%
import pandas as pd
from google.cloud import bigquery
from datetime import datetime,timezone,timedelta, date
from dateutil.relativedelta import relativedelta
BQ_TABLE="rax-architecture-sandbox.rax_gcp_billing.gcp_billing_export_v1_018918_BC80F7_298FEC"

# %%
# Thresholds
AMOUNT = 0.9
AMOUNT_CHANGED = 1
PERCENTAGE = 1.01
def parse_cost_changes(rows):
    flagged_items = []
    for item in rows:
        i1 = float(item["prev_day"])
        i2 = float(item["curr_day"])
        if (i1 > AMOUNT or i2 > AMOUNT) or (i1 != 0 and i2 != 0 and ((i2 /i1) >= PERCENTAGE or (i1 /i2) >= PERCENTAGE)) or abs(i2-i1) >= AMOUNT_CHANGED:
            flagged_items.append(item)
    return flagged_items

# %% [markdown]
# ## This query is to get the daily increase in consumption

# %%
client = bigquery.Client()
now = datetime.now(timezone.utc)
prev_utc = now -timedelta(2)
curr_utc = now - timedelta(1)

QUERY = (
    f"""SELECT
    project.name as project_name,
    sku.id as sku_id,
    sku.description as sku_def,
    service.id as service_id,
    service.description as service_def,
    SUM(CASE WHEN EXTRACT(DAY FROM usage_start_time) = {prev_utc.day} THEN cost ELSE 0 END) AS prev_day,
    SUM(CASE WHEN EXTRACT(DAY FROM usage_start_time) = {curr_utc.day} THEN cost ELSE 0 END) AS curr_day,
    FROM `{BQ_TABLE}`
    WHERE project.name = 'rax-datascience' 
    AND (DATE_TRUNC(usage_start_time, DAY) = "{prev_utc.strftime('%Y-%m-%d')}" or DATE_TRUNC(usage_start_time, DAY) = "{curr_utc.strftime('%Y-%m-%d')}")
    GROUP BY project_name, sku_id, sku_def, service_id, service_def
    ORDER BY project_name;"""
)
query_job = client.query(QUERY)  # API request
rows = query_job.result()
# Out:
# /Users/ejcv/miniconda3/envs/test_alerts/lib/python3.10/site-packages/google/auth/_default.py:79: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# /Users/ejcv/miniconda3/envs/test_alerts/lib/python3.10/site-packages/google/auth/_default.py:79: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)

# %%
rows.to_dataframe()
# Out:
#        project_name          sku_id  \
# 0   rax-datascience  C024-9C10-2A5B
# 1   rax-datascience  AB59-C5C0-8570
# 2   rax-datascience  A464-9020-6404
# 3   rax-datascience  8502-299A-ABAF
# 4   rax-datascience  22EB-AAE8-FBCD
# 5   rax-datascience  7756-ADEF-84F4
# 6   rax-datascience  8E10-82EB-6917
# 7   rax-datascience  B068-6B82-C017
# 8   rax-datascience  F01C-3EA0-06CD
# 9   rax-datascience  8AE7-5BBD-8F38
# 10  rax-datascience  978B-7150-4C95
# 11  rax-datascience  143F-A1B0-E0BE
# 12  rax-datascience  E5F0-6A5D-7BAD
# 13  rax-datascience  947D-3B46-7781
# 14  rax-datascience  1DF5-1F98-1DD1
# 15  rax-datascience  A5D6-43A2-28A7
# 16  rax-datascience  7870-010B-2763
# 17  rax-datascience  9ADA-9AED-1B24
# 18  rax-datascience  0D5D-6E23-4250
# 19  rax-datascience  993F-6B6B-DCC4
#
#                                               sku_def      service_id  \
# 0                                            CPU Time  29E7-DA93-CA13
# 1      BigQuery Storage API - Read Bytes Scanned (US)  DCC9-8DB9-673F
# 2                                          Build time  8B5D-EF7D-EB12
# 3                           Artifact Registry Storage  149C-F9EC-3994
# 4   Download Worldwide Destinations (excluding Asi...  95FF-2EF5-5EA1
# 5                      Secret version replica storage  EE82-7A5E-871C
# 6                                         Invocations  29E7-DA93-CA13
# 7                     Network Egress from us-central1  29E7-DA93-CA13
# 8                                         Memory Time  29E7-DA93-CA13
# 9            Multi-Region Standard Class B Operations  95FF-2EF5-5EA1
# 10                                            Storage  CAE2-A537-4A95
# 11                                         Log Volume  5490-F7B7-8DF6
# 12                       Standard Storage US Regional  95FF-2EF5-5EA1
# 13                                     Active Storage  24E6-581D-38E5
# 14                                           Analysis  24E6-581D-38E5
# 15                                               Jobs  1F14-4801-0E16
# 16               Regional Standard Class B Operations  95FF-2EF5-5EA1
# 17           Multi-Region Standard Class A Operations  95FF-2EF5-5EA1
# 18                   Standard Storage US Multi-region  95FF-2EF5-5EA1
# 19                                  Long Term Storage  24E6-581D-38E5
#
#              service_def  prev_day  curr_day
# 0        Cloud Functions  0.000028  0.000068
# 1   BigQuery Storage API  0.000000  0.000000
# 2            Cloud Build  0.000000  0.000000
# 3      Artifact Registry  0.137703  0.137708
# 4          Cloud Storage  0.000002  0.000000
# 5         Secret Manager  0.032013  0.031983
# 6        Cloud Functions  0.000000  0.000000
# 7        Cloud Functions  0.000000  0.000000
# 8        Cloud Functions  0.000004  0.000009
# 9          Cloud Storage  0.000050  0.000004
# 10     Source Repository  0.000000  0.000000
# 11         Cloud Logging  0.000000  0.000000
# 12         Cloud Storage  0.000000  0.000000
# 13              BigQuery  0.236588  0.231861
# 14              BigQuery  1.602938  1.701219
# 15       Cloud Scheduler  0.000000  0.000000
# 16         Cloud Storage  0.000020  0.000002
# 17         Cloud Storage  0.000010  0.000010
# 18         Cloud Storage  0.013977  0.014293
# 19              BigQuery  0.000810  0.003276

# %% [markdown]
# ## This query is to get the monthly consumption

# %%
now = datetime.now(timezone.utc)
prev_utc = now -relativedelta(months=+1)
curr_utc = now

QUERY = (
    f"""SELECT
    project.name as project_name,
    sku.id as sku_id,
    sku.description as sku_def,
    service.id as service_id,
    service.description as service_def,
    SUM(CASE WHEN EXTRACT(MONTH FROM usage_start_time) = {prev_utc.month} THEN cost ELSE 0 END) AS prev_month,
    SUM(CASE WHEN EXTRACT(MONTH FROM usage_start_time) = {curr_utc.month} THEN cost ELSE 0 END) AS curr_month,
    FROM `{BQ_TABLE}`
    WHERE project.name = 'rax-datascience' 
    AND (DATE_TRUNC(usage_start_time, MONTH) = "{prev_utc.strftime('%Y-%m-01')}" or DATE_TRUNC(usage_start_time, MONTH) = "{curr_utc.strftime('%Y-%m-01')}")
    GROUP BY project_name, sku_id, sku_def, service_id, service_def
    ORDER BY project_name;"""
)
query_job = client.query(QUERY)  # API request
rows = query_job.result()

# %% [markdown]
# ## This query is to get the weekly consumption

# %%
now = datetime.now(timezone.utc).isocalendar()[1]
prev_week = now - 1
curr_week = now

QUERY = (
    f"""SELECT
    project.name as project_name,
    sku.id as sku_id,
    sku.description as sku_def,
    service.id as service_id,
    service.description as service_def,
    SUM(CASE WHEN EXTRACT(ISOWEEK FROM usage_start_time) = {prev_week} THEN cost ELSE 0 END) AS prev_week,
    SUM(CASE WHEN EXTRACT(ISOWEEK FROM usage_start_time) = {curr_week} THEN cost ELSE 0 END) AS curr_week,
    FROM `{BQ_TABLE}`
    WHERE project.name = 'rax-datascience' 
    AND (EXTRACT(ISOWEEK FROM usage_start_time) = {prev_week} or EXTRACT(ISOWEEK FROM usage_start_time) = {curr_week})
    GROUP BY project_name, sku_id, sku_def, service_id, service_def
    ORDER BY project_name;"""
)
query_job = client.query(QUERY)  # API request
rows = query_job.result()

# %%
prev_week
# Out:
# 6

# %%
datetime.now(timezone.utc).isocalendar()
# Out:
# datetime.IsoCalendarDate(year=2022, week=7, weekday=5)

# %%
df = rows.to_dataframe()

# %%
df
# Out:
#        project_name          sku_id  \
# 0   rax-datascience  E5F0-6A5D-7BAD
# 1   rax-datascience  FED8-23FC-20EF
# 2   rax-datascience  947D-3B46-7781
# 3   rax-datascience  143F-A1B0-E0BE
# 4   rax-datascience  0D5D-6E23-4250
# 5   rax-datascience  7870-010B-2763
# 6   rax-datascience  6FE6-D064-82C6
# 7   rax-datascience  22EB-AAE8-FBCD
# 8   rax-datascience  1DF5-1F98-1DD1
# 9   rax-datascience  A5D6-43A2-28A7
# 10  rax-datascience  546B-E8F2-6FF5
# 11  rax-datascience  A464-9020-6404
# 12  rax-datascience  993F-6B6B-DCC4
# 13  rax-datascience  9ADA-9AED-1B24
# 14  rax-datascience  978B-7150-4C95
# 15  rax-datascience  8AE7-5BBD-8F38
# 16  rax-datascience  7756-ADEF-84F4
# 17  rax-datascience  8E10-82EB-6917
# 18  rax-datascience  B068-6B82-C017
# 19  rax-datascience  F01C-3EA0-06CD
# 20  rax-datascience  8502-299A-ABAF
# 21  rax-datascience  AB59-C5C0-8570
# 22  rax-datascience  C024-9C10-2A5B
#
#                                               sku_def      service_id  \
# 0                        Standard Storage US Regional  95FF-2EF5-5EA1
# 1                          Analysis Slots Attribution  24E6-581D-38E5
# 2                                      Active Storage  24E6-581D-38E5
# 3                                          Log Volume  5490-F7B7-8DF6
# 4                    Standard Storage US Multi-region  95FF-2EF5-5EA1
# 5                Regional Standard Class B Operations  95FF-2EF5-5EA1
# 6       BigQuery Flat Rate Flex for US (multi-region)  16B8-3DDA-9F10
# 7   Download Worldwide Destinations (excluding Asi...  95FF-2EF5-5EA1
# 8                                            Analysis  24E6-581D-38E5
# 9                                                Jobs  1F14-4801-0E16
# 10      Artifact Registry Network Intra Region Egress  149C-F9EC-3994
# 11                                         Build time  8B5D-EF7D-EB12
# 12                                  Long Term Storage  24E6-581D-38E5
# 13           Multi-Region Standard Class A Operations  95FF-2EF5-5EA1
# 14                                            Storage  CAE2-A537-4A95
# 15           Multi-Region Standard Class B Operations  95FF-2EF5-5EA1
# 16                     Secret version replica storage  EE82-7A5E-871C
# 17                                        Invocations  29E7-DA93-CA13
# 18                    Network Egress from us-central1  29E7-DA93-CA13
# 19                                        Memory Time  29E7-DA93-CA13
# 20                          Artifact Registry Storage  149C-F9EC-3994
# 21     BigQuery Storage API - Read Bytes Scanned (US)  DCC9-8DB9-673F
# 22                                           CPU Time  29E7-DA93-CA13
#
#                  service_def  prev_week  curr_week
# 0              Cloud Storage   0.000000   0.000000
# 1                   BigQuery   0.000000   0.000000
# 2                   BigQuery   1.838560   0.958063
# 3              Cloud Logging   0.000000   0.000000
# 4              Cloud Storage   0.094591   0.055638
# 5              Cloud Storage   0.000000   0.000022
# 6   BigQuery Reservation API   2.077777   0.000000
# 7              Cloud Storage   0.000641   0.000002
# 8                   BigQuery  26.693103   8.084075
# 9            Cloud Scheduler   0.000000   0.002764
# 10         Artifact Registry   0.000000   0.000000
# 11               Cloud Build   0.000000   0.000000
# 12                  BigQuery   0.003914   0.006963
# 13             Cloud Storage   0.000385   0.000040
# 14         Source Repository   0.000000   0.000000
# 15             Cloud Storage   0.000061   0.000054
# 16            Secret Manager   0.223828   0.144016
# 17           Cloud Functions   0.000000   0.000000
# 18           Cloud Functions   0.000000   0.000000
# 19           Cloud Functions   0.000000   0.000014
# 20         Artifact Registry   0.963867   0.620146
# 21      BigQuery Storage API   0.000000   0.000000
# 22           Cloud Functions   0.000000   0.000104

# %%
import pymsteams
import random

# %%
myTeamsMessage = pymsteams.ConnectorCard("https://raxglobal.webhook.office.com/webhookb2/958f9af0-e01e-4dd7-a71d-9d6e8f85e1e3@570057f4-73ef-41c8-bcbb-08db2fc15c2b/IncomingWebhook/ba01367e4b864dcbaa9b3df47f354687/03c80c6a-e55a-4acf-ab93-0ed10e8993aa")
myTeamsMessage.text("Hola bola")
myTeamsMessage.send()
# Out:
# True

# %%
with open("quotes.txt") as f:
    quotes = f.read().splitlines()

# %%
random.choice(quotes)
# Out:
# "“Why should I want to make anything up? Life's bad enough as it is without wanting to invent any more of it.” "

# %%
myTeamsMessage.text(f"Nothing to alert today \n \t {random.choice(quotes)}")
myTeamsMessage.send()
# Out:
# True

# %%
not []
# Out:
# True
